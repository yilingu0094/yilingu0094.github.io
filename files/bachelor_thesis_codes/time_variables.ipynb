# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import tensorflow as tf
from tensorflow import keras

test_data=pd.read_json("test.json")
train_data=pd.read_json("train.json")
test_data.reset_index(drop=True,inplace=True)
train_data.reset_index(drop=True,inplace=True)
print(test_data.shape)
print(train_data.shape)
# Out:
# (74659, 14)
# (49352, 15)

# %%
train_data.groupby('display_address')['latitude'].count()
# Out:
# display_address
#                                            135
# \tEast 10th Street and East 11th Street      1
# \tWashington Street                          1
#                                              2
#   Allen street                               1
#                                           ...
# williamsburg                                 2
# williamsburg  NO FEE                         1
# williamsburg - NO FEE                        8
# williamsburg Northside  NO FEE               1
# ▇_▶SEE TODAY*330 East 117th St               1
# Name: latitude, Length: 8826, dtype: int64

# %%
# created 不用精确，到月，分类变量

# %%
train_data['features'][0]    # 稀疏矩阵  one-hot
# Out:
# ['Dining Room',
#  'Pre-War',
#  'Laundry in Building',
#  'Dishwasher',
#  'Hardwood Floors',
#  'Dogs Allowed',
#  'Cats Allowed']

# %%
train_data["description"][0]
# Out:
# 'Spacious 1 Bedroom 1 Bathroom in Williamsburg!Apartment Features:- Renovated Eat in Kitchen With Dishwasher- Renovated Bathroom- Beautiful Hardwood Floors- Lots of Sunlight- Great Closet Space- Freshly Painted- Heat and Hot Water Included- Live in Super Nearby L, J, M & G Trains !<br /><br />Contact Information:Kenneth BeakExclusive AgentC: 064-692-8838Email: kagglemanager@renthop.com, Text or Email to schedule a private viewing!<br /><br /><br /><br /><br /><br /><br /><br /><br /><br /><br /><br /><br /><br /><br /><br /><p><a  website_redacted '

# %%
train_data['features'][1]
# Out:
# ['Doorman',
#  'Elevator',
#  'Laundry in Building',
#  'Dishwasher',
#  'Hardwood Floors',
#  'No Fee']

# %%
train_data["description"][1]
# Out:
# 'BRAND NEW GUT RENOVATED TRUE 2 BEDROOMFind yourself and your home in the center of it all. Steps from Grand Central Station, at the epicenter of Manhattan, The Centra combines convenience and luxury to create a perfectly balanced living experience. Offering newly renovated over sized apartment layouts.<br /><br />Full Time DoormanElevatorNewly Renovated HallwaysLaundry in BuildingOn-Site Parking Garage<br /><br />I operate with the utmost care and integrity. The client is my #1 priority. Contact me for a viewing of the great apartment, I\'m more than confident we\'ll find a place for you to call home.Call/Text Keon: Email: If you require a move within 30 days write "URGENT" in the subject email or text message to be taken with high priority.<br /><br />One Month Free - net effective rent listed<p><a  website_redacted '

# %%
train_data['features'][2]
# Out:
# ['Doorman',
#  'Elevator',
#  'Laundry in Building',
#  'Laundry in Unit',
#  'Dishwasher',
#  'Hardwood Floors']

# %% [markdown]
# ## value_counts()

# %%
manager_id=train_data["manager_id"].value_counts()

# %%
manager_id
# Out:
# e6472c7237327dd3903b3d6f6a94515a    2533
# 6e5c10246156ae5bdcd9b487ca99d96a     711
# 8f5a9c893f6d602f4953fcc0b8e6e9b4     410
# 62b685cc0d876c3a1a51d63a0d6a8082     402
# cb87dadbca78fad02b388dc9e8f25a5b     373
#                                     ...
# c50c5ab8e1440b548f3d22ece726a1d7       1
# f9c2f3218af267c9a96431eb784670ea       1
# ca454c185e07805685901413e553cbd3       1
# afb589862bfe7f12a58b9806b9d53ebd       1
# 9bbde1b1975fc748b08ad0b7527d1596       1
# Name: manager_id, Length: 3481, dtype: int64

# %%
train_data['building_id'].value_counts()
# Out:
# 0                                   8286
# 96274288c84ddd7d5c5d8e425ee75027     275
# 11e1dec9d14b1a9e528386a2504b3afc     215
# 80a120d6bc3aba97f40fee8c2204524b     213
# bb8658a3e432fb62a440615333376345     212
#                                     ...
# 250b21bd9c46a7bbab48feee2e2a60f0       1
# bd3ef6814d8565aab3c383121efd5c90       1
# f862a5b35ce6041c308d737c0b7fefe7       1
# 8fcfad24ea79487b334a08e70abac78e       1
# 32a6ada1b770ca045b46206ce3aa3517       1
# Name: building_id, Length: 7585, dtype: int64

# %%
train_data.head(50)
# Out:
#     bathrooms  bedrooms                       building_id  \
# 0         1.0         1  8579a0b0d54db803821a35a4a615e97a
# 1         1.0         2  b8e75fc949a6cd8225b455648a951712
# 2         1.0         2  cd759a988b8f23924b5a2058d5ab2b49
# 3         1.5         3  53a5b119ba8f7b61d4e010512e0dfc85
# 4         1.0         0  bfb9405149bfff42a92980b594c28234
# 5         1.0         3  300d27d8ba2adbcbc8c6f2bcbc1c6f9d
# 6         2.0         3  0d01cabe55fa5192cdbcabd5c585c1ea
# 7         1.0         0  d48767c37a934daaf0bbb0e58c755d0c
# 8         0.0         1  d1ca33a2853e64fad6e4009d5d5d168f
# 9         3.0         3  5f35dc2f0191baf109221752e6ee0c48
# 10        1.0         0  e74f18ba1001ceae531209fbdc702a58
# 11        1.0         2  d0234abbc01a982d54e8d446acc03405
# 12        1.0         0  2787598123c55dbf45b514958909c79c
# 13        1.0         1  bbc28059df5e21c49c103c46743631d4
# 14        2.0         2  810ddef9046abe7bd8278944c5809ae8
# 15        1.0         0  667d42b4651d26307c3f103a32cdb309
# 16        1.0         2  437454e6d44ae7c94f60b1b6507d084a
# 17        1.0         3  720302695e3e7d3d04275cd640fe58e4
# 18        1.0         1  530db036533ea851fabd1c5e7b9bc3d0
# 19        1.0         1                                 0
# 20        1.0         0  c1bcb85611d81b520a67c0828a9744b2
# 21        2.0         2  fa21c83e114de7fd5cedff34e93f4f1a
# 22        1.0         1  193808f62855020f2112500f8dc5e11a
# 23        1.0         1  1edde1c89233fb1b1a38c53e992b0756
# 24        1.0         1  f4875d036f1792722e87137a13a151b4
# 25        2.0         3  4dbba575a121cf478c8702c4d6edad70
# 26        1.0         2                                 0
# 27        1.0         2  f5da19cad075e248e88d0dd195bd2077
# 28        1.0         0  34c590e88c656abe3fc08b02bfffa9ed
# 29        1.0         2  d5f0baa9291f0a7160605019929b288d
# 30        1.0         2  644df980fb48947fe4eed6416cbefbee
# 31        1.0         0  951043fbb2622b2ab0e0623366d9f6dd
# 32        1.0         4  cedc1d16357dc7107fe57a08f120891c
# 33        1.0         1  79780be1514f645d7e6be99a3de696c5
# 34        1.0         3  bc51f6c095c976c49a28353f5788fe91
# 35        1.0         2  3eea9e38e194a173532a496dc2917bdb
# 36        1.0         1  d87ed33627efac7b4302cf04417a1e44
# 37        1.0         0  b6a45520b1b92242a19819c5ed4b554a
# 21     West 20th Street    [Doorman, Elevator, Dogs Allowed, Cats Allowed]
# 22     West 56th Street  [Doorman, Fitness Center, Elevator, PublicOutd...
# 23            First Ave  [Dining Room, Elevator, Dishwasher, Hardwood F...
# 24            E 79th St                      [Laundry in Building, No Fee]
# 25           Second Ave  [Laundry in Unit, Dishwasher, Hardwood Floors,...
# 26         Cliff Street  [Common Outdoor Space, Laundry In Unit, Doorma...
# 27     East 81st Street                       [Cats Allowed, Dogs Allowed]
# 28          E 75 Street  [Loft, Laundry in Unit, Dishwasher, Hardwood F...
# 29             W 43 St.  [Doorman, Elevator, Fitness Center, Garden/Pat...
# 30            Spring St  [Pre-War, Laundry in Unit, Dishwasher, Hardwoo...
# 31          W 64 Street               [Doorman, Elevator, Hardwood Floors]
# 32    West 109th Street                                          [Pre-War]
# 33       Suffolk Street                    [Elevator, Laundry in Building]
# 34              42nd St                                         [Elevator]
# 35     East 19th Street             [Elevator, Cats Allowed, Dogs Allowed]
# 36         Tenth Avenue  [Laundry in Unit, Dishwasher, Hardwood Floors,...
# 37          E 76 Street                            [Loft, Hardwood Floors]
# 38        President St.  [Dining Room, Laundry in Building, High Speed ...
# 39           E 25th St.  [Fireplace, Elevator, Furnished, Pre-War, Laun...
# 40            98 Harman         [Private Outdoor Space, No Fee, Exclusive]
# 41      West End Avenue  [Doorman, Elevator, Fitness Center, Loft, Laun...
# 42     Amsterdam Avenue                                                 []
# 43     East 12th Street              [Pre-War, Dogs Allowed, Cats Allowed]
# 44     East 46th Street  [Doorman, Elevator, Laundry in Building, Dishw...
# 45           E 96th St.  [Swimming Pool, Roof Deck, Doorman, Elevator, ...
# 46          Gold Street    [Doorman, Elevator, Dogs Allowed, Cats Allowed]
# 47     228 Jefferson St  [Common Outdoor Space, Cats Allowed, Dogs Allo...
# 48                e 83   [Common Outdoor Space, Doorman, Elevator, Laun...
# 49     East 68th Street                         [Pre-War, Hardwood Floors]
#
#     latitude  listing_id  longitude                        manager_id  \
# 0    40.7108     7170325   -73.9539  a10db4590843d78c784171a107bdacb4
# 1    40.7513     7092344   -73.9722  955db33477af4f40004820b4aed804a0
# 2    40.7575     7158677   -73.9625  c8b10a317b766204f08e613cef4ce7a0
# 3    40.7145     7211212   -73.9425  5ba989232d0489da1b5f2c45f6688adc
# 4    40.7439     7225292   -73.9743  2c3b41f588fbb5234d8a1e885a436cfa
# 5    40.7348     7226687   -73.9865  30a7951cfc21240e8c46b2d079d292e5
# 6    40.7302     7126989   -73.9826  9f39caedae295bf81e67463e6fd0af40
# 7    40.7769     7114138   -73.9467  9cbfa7a31ae9dfba70b4383636d99788
# 8    40.7346     7131094   -73.9811  b89e62bf8cdc98e9fb8b97d9bc627197
# 9    40.6990     7224815   -73.9943  d5d246c9d9d4e7079e5a0fc962d2f1a7
# 10   40.7723     7107333   -73.9510  7e22b26535b913275de0f9ff4f1d6965
# 11   40.7530     7088993   -73.9959  266121b077bc0ff6e11f697003a031fd
# 12   40.7610     7216312   -73.9990  66ad3cc67d71f41d549eef8b40ed26b9
# 48  [https://photos.renthop.com/2/7157060_a240a2a7...   4995
# 49  [https://photos.renthop.com/2/7173006_2eee1de6...   1895
#
#              street_address interest_level
# 0       145 Borinquen Place         medium
# 1             230 East 44th            low
# 2      405 East 56th Street         medium
# 3   792 Metropolitan Avenue         medium
# 4      340 East 34th Street            low
# 5      145 East 16th Street            low
# 6      410 East 13th Street            low
# 7          1661 York Avenue           high
# 8           346 E 19 Street            low
# 9           94 Hicks Street            low
# 10         420 E 80th St.\r            low
# 11             360 W 34 St.            low
# 12     620 West 42nd Street         medium
# 13         174 Thompson St.            low
# 14          360 E 65 Street            low
# 15      63A Division Avenue            low
# 16          235 E 46 Street            low
# 17     170 East 18th Street           high
# 18          308 W 77 Street            low
# 19          576 Main Street            low
# 20              655 2nd Ave            low
# 21     460 West 20th Street            low
# 22     500 West 56th Street            low
# 23            252 First Ave            low
# 24            510 E 79th St         medium
# 25           317 Second Ave            low
# 26             Cliff Street            low
# 27     407 East 81st Street            low
# 28          242 E 75 Street            low
# 29             350 W 43 St.            low
# 30             55 Spring St            low
# 31          244 W 64 Street           high
# 32    225 West 109th Street         medium
# 33        99 Suffolk Street         medium
# 34              830 42nd St           high
# 35     165 East 19th Street            low
# 36         697 Tenth Avenue            low
# 37          347 E 76 Street            low
# 38       1475 President St.            low
# 39           219 E 25th St.            low
# 40                98 Harman         medium
# 41      101 West End Avenue            low
# 42     706 Amsterdam Avenue           high
# 43     504 East 12th Street            low
# 44     235 East 46th Street            low
# 45           215 E 96th St.            low
# 46            2 Gold Street            low
# 47         228 Jefferson St            low
# 48                353 e 83             low
# 49     357 East 68th Street         medium

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49352 entries, 0 to 49351
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   bathrooms        49352 non-null  float64
#  1   bedrooms         49352 non-null  int64
#  2   building_id      49352 non-null  object
#  3   created          49352 non-null  object
#  4   description      49352 non-null  object
#  5   display_address  49352 non-null  object
#  6   features         49352 non-null  object
#  7   latitude         49352 non-null  float64
#  8   listing_id       49352 non-null  int64
#  9   longitude        49352 non-null  float64
#  10  manager_id       49352 non-null  object
#  11  photos           49352 non-null  object
#  12  price            49352 non-null  int64
#  13  street_address   49352 non-null  object
#  14  interest_level   49352 non-null  object
# dtypes: float64(3), int64(3), object(9)
# memory usage: 5.6+ MB

# %%
train_data.describe()
# Out:
#          bathrooms      bedrooms      latitude    listing_id     longitude  \
# count  49352.00000  49352.000000  49352.000000  4.935200e+04  49352.000000
# mean       1.21218      1.541640     40.741545  7.024055e+06    -73.955716
# std        0.50142      1.115018      0.638535  1.262746e+05      1.177912
# min        0.00000      0.000000      0.000000  6.811957e+06   -118.271000
# 25%        1.00000      1.000000     40.728300  6.915888e+06    -73.991700
# 50%        1.00000      1.000000     40.751800  7.021070e+06    -73.977900
# 75%        1.00000      2.000000     40.774300  7.128733e+06    -73.954800
# max       10.00000      8.000000     44.883500  7.753784e+06      0.000000
#
#               price
# count  4.935200e+04
# mean   3.830174e+03
# std    2.206687e+04
# min    4.300000e+01
# 25%    2.500000e+03
# 50%    3.150000e+03
# 75%    4.100000e+03
# max    4.490000e+06

# %%
import seaborn as sns
import matplotlib.pyplot as  plt
from matplotlib.pylab import mpl
color = sns.color_palette()
mpl.rcParams['font.sans-serif'] = ['SimHei']
figure=plt.figure(figsize=(8,6))
interest=train_data['interest_level'].value_counts()
sns.barplot(interest.index,interest.values)
plt.ylabel("出现次数")
plt.xlabel("兴趣程度")
plt.show()

# %%
# 变量选择，特征工程ok之后，欠采样过采样
# 欠采样 无放回抽样
# 过采样 有放回抽样
# 只改training data
# 不讨论了，直接走

# %%
# 1.变量选择对于模型性能的影响
# 2.模型
# （两段是分开的）

# %%
X = train_data[['bathrooms','bedrooms','latitude','listing_id','longitude','price']].to_numpy()

# %%
# X = train_data[['bathrooms','bedrooms','latitude','longitude','price']].to_numpy()

# %%
# y = train_data[['interest_level']].to_numpy().ravel()

# %% [markdown]
# # 特征工程 Eno

# %% [markdown]
# ## 1.时间变量转换

# %%
train_data['created'] = pd.to_datetime(train_data['created'])
train_data['month'] = train_data['created'].dt.month

# %%
train_data['month']
# Out:
# 0        6
# 1        6
# 2        6
# 3        6
# 4        6
#         ..
# 49347    4
# 49348    4
# 49349    4
# 49350    4
# 49351    4
# Name: month, Length: 49352, dtype: int64

# %%
train_data
# Out:
#        bathrooms  bedrooms                       building_id  \
# 0            1.0         1  8579a0b0d54db803821a35a4a615e97a
# 1            1.0         2  b8e75fc949a6cd8225b455648a951712
# 2            1.0         2  cd759a988b8f23924b5a2058d5ab2b49
# 3            1.5         3  53a5b119ba8f7b61d4e010512e0dfc85
# 4            1.0         0  bfb9405149bfff42a92980b594c28234
# ...          ...       ...                               ...
# 49347        1.0         3  92bbbf38baadfde0576fc496bd41749c
# 49348        1.0         2  5565db9b7cba3603834c4aa6f2950960
# 49349        1.0         1  67997a128056ee1ed7d046bbb856e3c7
# 49350        1.0         2  3c0574a740154806c18bdf1fddd3d966
# 49351        1.0         3  d89f514c3ed0abaae52cba7017ac0701
#
#                   created                                        description  \
# 0     2016-06-16 05:55:27  Spacious 1 Bedroom 1 Bathroom in Williamsburg!...
# 1     2016-06-01 05:44:33  BRAND NEW GUT RENOVATED TRUE 2 BEDROOMFind you...
# 2     2016-06-14 15:19:59  **FLEX 2 BEDROOM WITH FULL PRESSURIZED WALL**L...
# 3     2016-06-24 07:54:24  A Brand New 3 Bedroom 1.5 bath ApartmentEnjoy ...
# 4     2016-06-28 03:50:23  Over-sized Studio w abundant closets. Availabl...
# ...                   ...                                                ...
# 49347 2016-04-05 03:58:33  There is 700 square feet of recently renovated...
# 49348 2016-04-02 02:25:31  2 bedroom apartment with updated kitchen, rece...
# 49349 2016-04-26 05:42:03  No Brokers Fee * Never Lived 1 Bedroom 1 Bathr...
# 49350 2016-04-19 02:47:33  Wonderful Bright Chelsea 2 Bedroom apartment o...
# 49351 2016-04-20 05:34:00  ***PRIME MIDTOWN EAST OFF PARK AVE***TRUE 3 BE...
#
#             display_address  \
# 0       145 Borinquen Place
# 1                 East 44th
# 2          East 56th Street
# 3       Metropolitan Avenue
# 4          East 34th Street
# ...                     ...
# 49347          W 171 Street
# 49348              Broadway
# 49349  210 Brighton 15th St
# 49350      West 21st Street
# 49351             E 54th St
#
#                                                 features  latitude  \
# 0      [Dining Room, Pre-War, Laundry in Building, Di...   40.7108
# 1      [Doorman, Elevator, Laundry in Building, Dishw...   40.7513
# 2      [Doorman, Elevator, Laundry in Building, Laund...   40.7575
# 3                                                     []   40.7145
# 4      [Doorman, Elevator, Fitness Center, Laundry in...   40.7439
# ...                                                  ...       ...
# 49347            [Elevator, Dishwasher, Hardwood Floors]   40.8433
# 49348  [Common Outdoor Space, Cats Allowed, Dogs Allo...   40.8198
# 49349  [Dining Room, Elevator, Pre-War, Laundry in Bu...   40.5765
# 49350  [Pre-War, Laundry in Unit, Dishwasher, No Fee,...   40.7448
# 49351  [Dining Room, Elevator, Laundry in Building, D...   40.7594
#
#        listing_id  longitude                        manager_id  \
# 0         7170325   -73.9539  a10db4590843d78c784171a107bdacb4
# 1         7092344   -73.9722  955db33477af4f40004820b4aed804a0
# 2         7158677   -73.9625  c8b10a317b766204f08e613cef4ce7a0
# 3         7211212   -73.9425  5ba989232d0489da1b5f2c45f6688adc
# 4         7225292   -73.9743  2c3b41f588fbb5234d8a1e885a436cfa
# ...           ...        ...                               ...
# 49347     6824800   -73.9396  a61e21da3ba18c7a3d54cfdcc247e1f8
# 49348     6813268   -73.9578  8f90e5e10e8a2d7cf997f016d89230eb
# 49349     6927093   -73.9554  a10db4590843d78c784171a107bdacb4
# 49350     6892816   -74.0017  c3cd45f4381ac371507090e9ffabea80
# 49351     6901023   -73.9712  e90f2ded843cdb2efd65ef47d9fc8029
#
#                                                   photos  price  \
# 0      [https://photos.renthop.com/2/7170325_3bb5ac84...   2400
# 1      [https://photos.renthop.com/2/7092344_7663c19a...   3800
# 2      [https://photos.renthop.com/2/7158677_c897a134...   3495
# 3      [https://photos.renthop.com/2/7211212_1ed4542e...   3000
# 4      [https://photos.renthop.com/2/7225292_901f1984...   2795
# ...                                                  ...    ...
# 49347  [https://photos.renthop.com/2/6824800_0682be16...   2800
# 49348  [https://photos.renthop.com/2/6813268_1e6fcc32...   2395
# 49349  [https://photos.renthop.com/2/6927093_93a52104...   1850
# 49350  [https://photos.renthop.com/2/6892816_1a8d087a...   4195
# 49351  [https://photos.renthop.com/2/6901023_02052d90...   4280
#
#                 street_address interest_level  month
# 0          145 Borinquen Place         medium      6
# 1                230 East 44th            low      6
# 2         405 East 56th Street         medium      6
# 3      792 Metropolitan Avenue         medium      6
# 4         340 East 34th Street            low      6
# ...                        ...            ...    ...
# 49347         620 W 171 Street            low      4
# 49348            3333 Broadway         medium      4
# 49349     210 Brighton 15th St         medium      4
# 49350     350 West 21st Street         medium      4
# 49351            123 E 54th St           high      4
#
# [49352 rows x 16 columns]

# %%
ENO_Date_CSV = train_data

# %%
ENO_Date_CSV.to_csv("ENO_Date_CSV.csv")

# %%
train_data['features'][0]
# Out:
# ['Dining Room',
#  'Pre-War',
#  'Laundry in Building',
#  'Dishwasher',
#  'Hardwood Floors',
#  'Dogs Allowed',
#  'Cats Allowed']

# %%
print(train_data['features'][0])
# Out:
# ['Dining Room', 'Pre-War', 'Laundry in Building', 'Dishwasher', 'Hardwood Floors', 'Dogs Allowed', 'Cats Allowed']

# %% [markdown]
# ## 把Y改为数值

# %%
interest_classification = train_data[['interest_level']]

# %%
# for the logistic rergession, it supports only ordinal output for the softmax case
# the softmax case has to do manually

from sklearn.preprocessing import OrdinalEncoder

ordinal_encoder = OrdinalEncoder()
interest_classification_encoded = ordinal_encoder.fit_transform(interest_classification)

# %%
y = interest_classification_encoded.ravel()
y

# %%
y.shape

# %%
X.shape

# %%
# train validation split

from sklearn.model_selection import train_test_split
X_train, X_validation, y_train, y_validation = train_test_split(X, y, test_size=0.3)

# %%
# normalization process

X_train_norm = np.ones(X_train.shape)
X_validation_norm = np.ones(X_validation.shape)

num_features = X.shape[1]

for i in range(num_features):
    X_train_norm[:,i] = (X_train[:,i] - X[:,i].mean())/X[:,i].std()
    X_validation_norm[:,i] = (X_validation[:,i] - X[:,i].mean())/X[:,i].std()

# %%
y_validation

# %%
X_train_norm.shape[1]

# %%
ordinal_encoder.categories_

# %%
## 一共三类
# 0:high
# 1:low
# 2:medium

# %%
# 把分类的作为feature放入文件，名为interest_level_class
train_data['interest_level_class'] = y

# %% [markdown]
# ### Correlation coefficient

# %%
# 显示线性关系
corrr = train_data.corr()
corrr['interest_level_class'].sort_values(ascending=False)

# %%
train_data.head()

# %% [markdown]
# # 1. A more complicated NN Model

# %%
mirrored_strategy = tf.distribute.MirroredStrategy(
    cross_device_ops=tf.distribute.HierarchicalCopyAllReduce())

# %% [raw]
# METRICS = [
#       keras.metrics.BinaryAccuracy(name='accuracy'),
#       keras.metrics.Precision(name='precision'),
#       keras.metrics.Recall(name='recall'),
#       keras.metrics.AUC(name='auc'),
# ]

# %%
with mirrored_strategy.scope():
    model = keras.Sequential([
        keras.layers.Dense(50, activation='relu', input_shape=[X_train_norm.shape[1]]),
        keras.layers.Dense(50, activation='relu'),
        keras.layers.Dense(10, activation='relu'),
      #  keras.layers.Dense(100, activation='relu'),
    #    keras.layers.Dense(100, activation='relu'),
     #   keras.layers.Dense(100, activation='relu'),
       # keras.layers.Dense(100, activation='relu'),
        #keras.layers.Dense(100, activation='relu'),
        #keras.layers.Dense(100, activation='relu'),
        #keras.layers.Dense(100, activation='relu'),
        keras.layers.Dense(6, activation='softmax')
    ])
    
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['acc'])
        
    #model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=METRICS)

# %%
history = model.fit(X_train_norm, y_train,
                    validation_data = (X_validation_norm, y_validation), epochs=100, batch_size = 200)

# %%
plt.figure(figsize=(10,7))
plt.plot(history.history['acc'], 'r', label = 'training accuracy')
plt.plot(history.history['val_acc'], label = 'validation accuracy')
plt.legend(loc = 'best')
plt.show()
# 各个类的准确率

# %% [markdown]
# # 2. Basic NN Model

# %%
with mirrored_strategy.scope():
    model = keras.models.Sequential([
        keras.layers.Flatten(input_shape=[X_train_norm.shape[1]]),
        keras.layers.Dense(3)
    ])
    
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['acc'])
model.summary()

# %%
history2 = model.fit(X_train_norm, y_train,
                    validation_data=(X_validation_norm, y_validation), epochs=35, batch_size = 1000)

# %%
plt.figure(figsize=(10,7))
plt.plot(history.history['acc'], 'r', label = 'training accuracy')
plt.plot(history.history['val_acc'], label = 'validation accuracy')
plt.legend(loc = 'best')
plt.show()
